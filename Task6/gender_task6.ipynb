# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

BASE_DIR = '/kaggle/input/utkface-new/UTKFace'
IMG_SIZE = (128, 128)
BATCH_SIZE = 128
EPOCHS = 100
# Out:
# 2025-08-05 14:07:28.618860: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754402848.971693      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754402849.070192      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_data():
    images, genders = [], []
    for file in tqdm(os.listdir(BASE_DIR)):
        temp = file.split('_')
        if len(temp) >= 2 and temp[1].isdigit():
            genders.append(int(temp[1]))
            img_path = os.path.join(BASE_DIR, file)
            img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE, color_mode='grayscale')
            img = tf.keras.preprocessing.image.img_to_array(img) / 255.0
            images.append(img)
    
    images = np.array(images)
    genders = np.array(genders)
    return images, genders

# %%
def get_data_augmentation():
    return tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.2),
    ])

# %%
def build_model():
    inputs = Input(shape=(128, 128, 1))
    x = get_data_augmentation()(inputs)
    
    x = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = Dropout(0.5)(x)
    
    gender_output = Dense(1, activation='sigmoid', name='gender')(x)
    
    model = Model(inputs=inputs, outputs=gender_output)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    model.summary()
    return model

# %%
def compute_gender_class_weights(genders):
    classes = np.unique(genders)
    class_weights = compute_class_weight('balanced', classes=classes, y=genders)
    return {0: class_weights[0], 1: class_weights[1]}

# %%
def compute_sample_weights(genders, class_weights):
    sample_weights = np.zeros(len(genders))
    for i, gender in enumerate(genders):
        sample_weights[i] = class_weights[gender]
    return sample_weights

# %%
images, genders = load_data()
X_temp, X_test, y_temp_gender, y_test_gender = train_test_split(
    images, genders, test_size=0.2, random_state=42, shuffle=True
)
X_train, X_val, y_train_gender, y_val_gender = train_test_split(
    X_temp, y_temp_gender, test_size=0.25, random_state=42, shuffle=True 
)

class_weights = compute_gender_class_weights(y_train_gender)
sample_weights = compute_sample_weights(y_train_gender, class_weights)
model = build_model()
checkpoint = ModelCheckpoint(
        '/kaggle/working/gendertask6.weights.h5',
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
        verbose=1
)
early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=10,
        restore_best_weights=True,
        mode='max'
)
history = model.fit(
        X_train,
        y_train_gender,
        validation_data=(X_val, y_val_gender),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=[checkpoint,early_stopping],
        sample_weight=sample_weights,
        verbose=1
)

final_train_acc = history.history['accuracy'][-1]
final_val_acc = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

print(f"\nFinal Training Accuracy: {final_train_acc:.4f}")
print(f"Final Validation Accuracy: {final_val_acc:.4f}")
print(f"Final Training Loss: {final_train_loss:.4f}")
print(f"Final Validation Loss: {final_val_loss:.4f}")

model.load_weights('/kaggle/working/gendertask6.weights.h5')
test_loss, test_accuracy = model.evaluate(X_test, y_test_gender, verbose=1)
#Computing precision, recall and F1 score
y_pred = model.predict(X_test, verbose=0)
y_pred_binary = (y_pred > 0.5).astype(int).flatten()
precision = precision_score(y_test_gender, y_pred_binary)
recall = recall_score(y_test_gender, y_pred_binary)
f1 = f1_score(y_test_gender, y_pred_binary)
cm = confusion_matrix(y_test_gender, y_pred_binary)
print(f"Test Gender Accuracy: {test_accuracy:.4f}")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Precision: {precision:.4f}")
print(f"Test Recall: {recall:.4f}")
print(f"Test F1 Score: {f1:.4f}")

#Plotting confusion matrix
class_labels = ["Male", "Female"]
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix for Gender Classification")
plt.show()
model.save('/kaggle/working/gendertask6.h5')

plt.figure(figsize=(10, 4))   
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs. Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 23708/23708 [03:08<00:00, 126.04it/s]
# I0000 00:00:1754403058.273598      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1754403058.274319      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,194,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gender (Dense)                  │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,288,129 (16.36 MB)
#  Trainable params: 4,287,681 (16.36 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/100
# I0000 00:00:1754403069.266504      96 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5979 - loss: 1.9312
# Epoch 1: val_accuracy improved from -inf to 0.47807, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 29s 160ms/step - accuracy: 0.5981 - loss: 1.9237 - val_accuracy: 0.4781 - val_loss: 7.6517
# Epoch 2/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6689 - loss: 0.6563
# Epoch 2: val_accuracy did not improve from 0.47807
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 16s 146ms/step - accuracy: 0.6690 - loss: 0.6563 - val_accuracy: 0.4781 - val_loss: 9.5414
# Epoch 3/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6960 - loss: 0.6278
# Epoch 3: val_accuracy improved from 0.47807 to 0.49325, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - accuracy: 0.6960 - loss: 0.6278 - val_accuracy: 0.4933 - val_loss: 3.2380
# Epoch 4/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.7011 - loss: 0.6093
# Epoch 4: val_accuracy improved from 0.49325 to 0.66301, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 150ms/step - accuracy: 0.7011 - loss: 0.6093 - val_accuracy: 0.6630 - val_loss: 0.7824
# Epoch 5/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7164 - loss: 0.6003
# Epoch 5: val_accuracy improved from 0.66301 to 0.77119, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.7165 - loss: 0.6002 - val_accuracy: 0.7712 - val_loss: 0.5362
# Epoch 6/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7247 - loss: 0.5957
# Epoch 6: val_accuracy improved from 0.77119 to 0.77942, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.7246 - loss: 0.5957 - val_accuracy: 0.7794 - val_loss: 0.5135
# Epoch 7/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7304 - loss: 0.5765
# Epoch 7: val_accuracy did not improve from 0.77942
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 154ms/step - accuracy: 0.7305 - loss: 0.5765 - val_accuracy: 0.7718 - val_loss: 0.5450
# Epoch 8/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.7366 - loss: 0.5626
# Epoch 8: val_accuracy improved from 0.77942 to 0.80135, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 156ms/step - accuracy: 0.7367 - loss: 0.5625 - val_accuracy: 0.8013 - val_loss: 0.4860
# Epoch 9/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7414 - loss: 0.5594
# Epoch 9: val_accuracy did not improve from 0.80135
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.7415 - loss: 0.5592 - val_accuracy: 0.7514 - val_loss: 0.5463
# Epoch 10/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7573 - loss: 0.5531
# Epoch 10: val_accuracy improved from 0.80135 to 0.81506, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 154ms/step - accuracy: 0.7573 - loss: 0.5530 - val_accuracy: 0.8151 - val_loss: 0.4523
# Epoch 11/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7659 - loss: 0.5315
# Epoch 11: val_accuracy did not improve from 0.81506
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.7659 - loss: 0.5313 - val_accuracy: 0.8148 - val_loss: 0.4565
# Epoch 12/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7719 - loss: 0.5209
# Epoch 12: val_accuracy improved from 0.81506 to 0.81949, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 154ms/step - accuracy: 0.7719 - loss: 0.5209 - val_accuracy: 0.8195 - val_loss: 0.4412
# Epoch 13/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.7827 - loss: 0.5110
# Epoch 13: val_accuracy improved from 0.81949 to 0.83298, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 154ms/step - accuracy: 0.7827 - loss: 0.5109 - val_accuracy: 0.8330 - val_loss: 0.4414
# Epoch 14/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7895 - loss: 0.4997
# Epoch 14: val_accuracy did not improve from 0.83298
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.7895 - loss: 0.4997 - val_accuracy: 0.7250 - val_loss: 0.5703
# Epoch 15/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7945 - loss: 0.4949
# Epoch 15: val_accuracy did not improve from 0.83298
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.7944 - loss: 0.4948 - val_accuracy: 0.7115 - val_loss: 0.5971
# Epoch 16/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8002 - loss: 0.4850
# Epoch 16: val_accuracy did not improve from 0.83298
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8002 - loss: 0.4851 - val_accuracy: 0.6944 - val_loss: 0.6834
# Epoch 17/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7905 - loss: 0.5049
# Epoch 17: val_accuracy improved from 0.83298 to 0.84732, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 154ms/step - accuracy: 0.7906 - loss: 0.5046 - val_accuracy: 0.8473 - val_loss: 0.4189
# Epoch 18/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8136 - loss: 0.4690
# Epoch 18: val_accuracy did not improve from 0.84732
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8136 - loss: 0.4689 - val_accuracy: 0.7084 - val_loss: 0.6529
# Epoch 19/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8035 - loss: 0.4772
# Epoch 19: val_accuracy did not improve from 0.84732
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8036 - loss: 0.4770 - val_accuracy: 0.8349 - val_loss: 0.4273
# Epoch 20/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8149 - loss: 0.4704
# Epoch 20: val_accuracy improved from 0.84732 to 0.85386, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.8149 - loss: 0.4703 - val_accuracy: 0.8539 - val_loss: 0.4018
# Epoch 21/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8185 - loss: 0.4537
# Epoch 21: val_accuracy did not improve from 0.85386
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8184 - loss: 0.4538 - val_accuracy: 0.8336 - val_loss: 0.4457
# Epoch 22/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8153 - loss: 0.4651
# Epoch 22: val_accuracy did not improve from 0.85386
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8154 - loss: 0.4650 - val_accuracy: 0.8197 - val_loss: 0.4672
# Epoch 23/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8192 - loss: 0.4590
# Epoch 23: val_accuracy did not improve from 0.85386
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8193 - loss: 0.4589 - val_accuracy: 0.8233 - val_loss: 0.4479
# Epoch 24/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8303 - loss: 0.4412
# Epoch 24: val_accuracy did not improve from 0.85386
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8303 - loss: 0.4413 - val_accuracy: 0.8387 - val_loss: 0.4430
# Epoch 25/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8330 - loss: 0.4459
# Epoch 25: val_accuracy improved from 0.85386 to 0.87895, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.8330 - loss: 0.4458 - val_accuracy: 0.8790 - val_loss: 0.3615
# Epoch 26/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8294 - loss: 0.4466
# Epoch 26: val_accuracy did not improve from 0.87895
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8295 - loss: 0.4465 - val_accuracy: 0.8129 - val_loss: 0.4829
# Epoch 27/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8320 - loss: 0.4528
# Epoch 27: val_accuracy did not improve from 0.87895
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8320 - loss: 0.4529 - val_accuracy: 0.8452 - val_loss: 0.4179
# Epoch 28/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8317 - loss: 0.4554
# Epoch 28: val_accuracy did not improve from 0.87895
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8317 - loss: 0.4552 - val_accuracy: 0.8743 - val_loss: 0.3714
# Epoch 29/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8386 - loss: 0.4427
# Epoch 29: val_accuracy did not improve from 0.87895
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8385 - loss: 0.4427 - val_accuracy: 0.8697 - val_loss: 0.3889
# Epoch 30/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8464 - loss: 0.4266
# Epoch 30: val_accuracy did not improve from 0.87895
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8464 - loss: 0.4267 - val_accuracy: 0.8526 - val_loss: 0.4179
# Epoch 31/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8402 - loss: 0.4217
# Epoch 31: val_accuracy did not improve from 0.87895
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8402 - loss: 0.4218 - val_accuracy: 0.8186 - val_loss: 0.4607
# Epoch 32/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8364 - loss: 0.4569
# Epoch 32: val_accuracy did not improve from 0.87895
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8365 - loss: 0.4568 - val_accuracy: 0.8735 - val_loss: 0.3964
# Epoch 33/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8453 - loss: 0.4310
# Epoch 33: val_accuracy improved from 0.87895 to 0.88549, saving model to /kaggle/working/gendertask6.weights.h5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 153ms/step - accuracy: 0.8452 - loss: 0.4311 - val_accuracy: 0.8855 - val_loss: 0.3622
# Epoch 34/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8536 - loss: 0.4229
# Epoch 34: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8536 - loss: 0.4229 - val_accuracy: 0.8806 - val_loss: 0.3616
# Epoch 35/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8527 - loss: 0.4149
# Epoch 35: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8527 - loss: 0.4150 - val_accuracy: 0.8551 - val_loss: 0.4148
# Epoch 36/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8445 - loss: 0.4296
# Epoch 36: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8445 - loss: 0.4296 - val_accuracy: 0.8602 - val_loss: 0.3898
# Epoch 37/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8463 - loss: 0.4278
# Epoch 37: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8463 - loss: 0.4277 - val_accuracy: 0.8566 - val_loss: 0.4092
# Epoch 38/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8520 - loss: 0.4167
# Epoch 38: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.8520 - loss: 0.4168 - val_accuracy: 0.7980 - val_loss: 0.5159
# Epoch 39/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8505 - loss: 0.4169
# Epoch 39: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8505 - loss: 0.4170 - val_accuracy: 0.8720 - val_loss: 0.3794
# Epoch 40/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8549 - loss: 0.4140
# Epoch 40: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8549 - loss: 0.4140 - val_accuracy: 0.8695 - val_loss: 0.3754
# Epoch 41/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8540 - loss: 0.4161
# Epoch 41: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8540 - loss: 0.4161 - val_accuracy: 0.8779 - val_loss: 0.3627
# Epoch 42/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8609 - loss: 0.4136
# Epoch 42: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8608 - loss: 0.4136 - val_accuracy: 0.8631 - val_loss: 0.3978
# Epoch 43/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8547 - loss: 0.4148
# Epoch 43: val_accuracy did not improve from 0.88549
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 17s 151ms/step - accuracy: 0.8548 - loss: 0.4148 - val_accuracy: 0.8669 - val_loss: 0.3755
#
# Final Training Accuracy: 0.8568
# Final Validation Accuracy: 0.8669
# Final Training Loss: 0.4165
# Final Validation Loss: 0.3755
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8838 - loss: 0.3538
# Test Gender Accuracy: 0.8745
# Test Loss: 0.3649
# Test Precision: 0.8946
# Test Recall: 0.8327
# Test F1 Score: 0.8626
