# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')


BASE_DIR = '/kaggle/input/utkface-new/UTKFace'
IMG_SIZE = (128, 128)
BATCH_SIZE = 128
EPOCHS = 100
MAX_AGE = 116.0
# Out:
# 2025-08-05 14:43:11.973528: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754404992.164537      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754404992.220888      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_data():
    images, ages = [], []
    for file in tqdm(os.listdir(BASE_DIR)):
        temp = file.split('_')
        if len(temp) >= 1 and temp[0].isdigit():
            ages.append(int(temp[0]) / MAX_AGE)  
            img_path = os.path.join(BASE_DIR, file)
            img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE, color_mode='grayscale')
            img = tf.keras.preprocessing.image.img_to_array(img) / 255.0
            images.append(img)
    
    images = np.array(images)
    ages = np.array(ages)
    return images, ages

# %%
def get_data_augmentation():
    return tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.2),
        tf.keras.layers.RandomContrast(0.1),
    ])

# %%
#Gradual decay of learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.001
    return initial_lr * (1.0 / (1.0 + 0.02 * epoch))

# %%
def build_model():
    inputs = Input(shape=(128, 128, 1))
    x = get_data_augmentation()(inputs)
    
    x = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = Dropout(0.6)(x)
    x = Dense(128, activation='relu')(x) 
    
    age_output = Dense(1, name='age')(x)  
    
    model = Model(inputs=inputs, outputs=age_output)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='mean_squared_error', 
        metrics=['mae']
    )
    model.summary()
    return model

# %%
def check_data_distribution(X_train, y_train_age, X_val, y_val_age, X_test, y_test_age):
    print(f"Training set: {len(X_train)} samples, Age mean: {np.mean(y_train_age) * MAX_AGE:.2f}")
    print(f"Validation set: {len(X_val)} samples, Age mean: {np.mean(y_val_age) * MAX_AGE:.2f}")
    print(f"Test set: {len(X_test)} samples, Age mean: {np.mean(y_test_age) * MAX_AGE:.2f}")

# %%
images, ages = load_data()
X_temp, X_test, y_temp_age, y_test_age = train_test_split(
    images, ages, test_size=0.1, random_state=42, shuffle=True
)
X_train, X_val, y_train_age, y_val_age = train_test_split(
    X_temp, y_temp_age,random_state=42, shuffle=True
)

check_data_distribution(X_train, y_train_age, X_val, y_val_age, X_test, y_test_age)
model = build_model()
checkpoint = ModelCheckpoint(
    '/kaggle/working/agetask6.weights.h5',
    monitor='val_mae',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_mae',
    patience=10,
    restore_best_weights=True,
    mode='min'
)
lr_scheduler = LearningRateScheduler(lr_schedule)
history = model.fit(
    X_train,
    y_train_age,
    validation_data=(X_val, y_val_age),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[checkpoint, early_stopping, lr_scheduler],
    verbose=1
)

model.load_weights('/kaggle/working/agetask6.weights.h5')
test_results = model.evaluate(
    X_test, y_test_age,
    verbose=0,
    return_dict=True
)
print("Test results:", test_results)
test_total_loss = test_results['loss']
test_age_mae = test_results['mae'] * MAX_AGE
print(f"Test Age MAE: {test_age_mae:.4f} years")
print(f"Test Total Loss: {test_total_loss:.4f}")
model.save('/kaggle/working/agetask6.h5')

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training Age MAE')
plt.plot(history.history['val_mae'], label='Validation Age MAE')
plt.title('Training vs Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.ylim(0, 0.2)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 23708/23708 [01:58<00:00, 200.63it/s]
# Training set: 16002 samples, Age mean: 33.43
# Validation set: 5335 samples, Age mean: 32.99
# Test set: 2371 samples, Age mean: 33.18
# I0000 00:00:1754405125.076506      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1754405125.077233      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     4,194,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ age (Dense)                     │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,617,345 (17.61 MB)
#  Trainable params: 4,616,385 (17.61 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/100
# I0000 00:00:1754405137.770916      98 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 39.5543 - mae: 2.8286
# Epoch 1: val_mae improved from inf to 0.14014, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 34s 175ms/step - loss: 39.3258 - mae: 2.8166 - val_loss: 0.1304 - val_mae: 0.1401 - learning_rate: 0.0010
# Epoch 2/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - loss: 0.2164 - mae: 0.2629
# Epoch 2: val_mae did not improve from 0.14014
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 160ms/step - loss: 0.2160 - mae: 0.2624 - val_loss: 0.1295 - val_mae: 0.1421 - learning_rate: 9.8039e-04
# Epoch 3/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.1517 - mae: 0.1796
# Epoch 3: val_mae improved from 0.14014 to 0.13985, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 165ms/step - loss: 0.1516 - mae: 0.1795 - val_loss: 0.1285 - val_mae: 0.1398 - learning_rate: 9.6154e-04
# Epoch 4/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.1362 - mae: 0.1553
# Epoch 4: val_mae improved from 0.13985 to 0.13291, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - loss: 0.1361 - mae: 0.1552 - val_loss: 0.1263 - val_mae: 0.1329 - learning_rate: 9.4340e-04
# Epoch 5/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.1317 - mae: 0.1425
# Epoch 5: val_mae improved from 0.13291 to 0.12969, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.1317 - mae: 0.1425 - val_loss: 0.1248 - val_mae: 0.1297 - learning_rate: 9.2593e-04
# Epoch 6/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.1395 - mae: 0.1380
# Epoch 6: val_mae did not improve from 0.12969
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - loss: 0.1394 - mae: 0.1380 - val_loss: 0.1252 - val_mae: 0.1301 - learning_rate: 9.0909e-04
# Epoch 7/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1235 - mae: 0.1306
# Epoch 7: val_mae improved from 0.12969 to 0.12672, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - loss: 0.1235 - mae: 0.1306 - val_loss: 0.1226 - val_mae: 0.1267 - learning_rate: 8.9286e-04
# Epoch 8/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.1219 - mae: 0.1298
# Epoch 8: val_mae did not improve from 0.12672
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: 0.1219 - mae: 0.1298 - val_loss: 0.1222 - val_mae: 0.1272 - learning_rate: 8.7719e-04
# Epoch 9/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1204 - mae: 0.1292
# Epoch 9: val_mae improved from 0.12672 to 0.12556, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.1204 - mae: 0.1292 - val_loss: 0.1200 - val_mae: 0.1256 - learning_rate: 8.6207e-04
# Epoch 10/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.1195 - mae: 0.1299
# Epoch 10: val_mae did not improve from 0.12556
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1195 - mae: 0.1299 - val_loss: 0.1186 - val_mae: 0.1259 - learning_rate: 8.4746e-04
# Epoch 11/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1184 - mae: 0.1300
# Epoch 11: val_mae did not improve from 0.12556
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1184 - mae: 0.1300 - val_loss: 0.1189 - val_mae: 0.1269 - learning_rate: 8.3333e-04
# Epoch 12/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1173 - mae: 0.1283
# Epoch 12: val_mae did not improve from 0.12556
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1173 - mae: 0.1283 - val_loss: 0.1177 - val_mae: 0.1271 - learning_rate: 8.1967e-04
# Epoch 13/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1177 - mae: 0.1299
# Epoch 13: val_mae did not improve from 0.12556
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: 0.1176 - mae: 0.1299 - val_loss: 0.1170 - val_mae: 0.1263 - learning_rate: 8.0645e-04
# Epoch 14/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1152 - mae: 0.1277
# Epoch 14: val_mae improved from 0.12556 to 0.12528, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - loss: 0.1152 - mae: 0.1277 - val_loss: 0.1151 - val_mae: 0.1253 - learning_rate: 7.9365e-04
# Epoch 15/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1151 - mae: 0.1290
# Epoch 15: val_mae improved from 0.12528 to 0.12505, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - loss: 0.1151 - mae: 0.1290 - val_loss: 0.1137 - val_mae: 0.1251 - learning_rate: 7.8125e-04
# Epoch 16/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1135 - mae: 0.1282
# Epoch 16: val_mae improved from 0.12505 to 0.12487, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.1135 - mae: 0.1282 - val_loss: 0.1137 - val_mae: 0.1249 - learning_rate: 7.6923e-04
# Epoch 17/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1129 - mae: 0.1275
# Epoch 17: val_mae improved from 0.12487 to 0.12366, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - loss: 0.1129 - mae: 0.1275 - val_loss: 0.1122 - val_mae: 0.1237 - learning_rate: 7.5758e-04
# Epoch 18/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1121 - mae: 0.1283
# Epoch 18: val_mae improved from 0.12366 to 0.12332, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.1121 - mae: 0.1282 - val_loss: 0.1103 - val_mae: 0.1233 - learning_rate: 7.4627e-04
# Epoch 19/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1110 - mae: 0.1292
# Epoch 19: val_mae did not improve from 0.12332
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1110 - mae: 0.1292 - val_loss: 0.1104 - val_mae: 0.1250 - learning_rate: 7.3529e-04
# Epoch 20/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1093 - mae: 0.1267
# Epoch 20: val_mae did not improve from 0.12332
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: 0.1093 - mae: 0.1267 - val_loss: 0.1086 - val_mae: 0.1249 - learning_rate: 7.2464e-04
# Epoch 21/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1079 - mae: 0.1263
# Epoch 21: val_mae did not improve from 0.12332
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: 0.1079 - mae: 0.1263 - val_loss: 0.1084 - val_mae: 0.1262 - learning_rate: 7.1429e-04
# Epoch 22/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1078 - mae: 0.1283
# Epoch 22: val_mae did not improve from 0.12332
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: 0.1078 - mae: 0.1283 - val_loss: 0.1071 - val_mae: 0.1262 - learning_rate: 7.0423e-04
# Epoch 23/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1059 - mae: 0.1259
# Epoch 23: val_mae did not improve from 0.12332
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: 0.1059 - mae: 0.1259 - val_loss: 0.1050 - val_mae: 0.1241 - learning_rate: 6.9444e-04
# Epoch 24/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1052 - mae: 0.1270
# Epoch 24: val_mae did not improve from 0.12332
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 167ms/step - loss: 0.1052 - mae: 0.1270 - val_loss: 0.1045 - val_mae: 0.1238 - learning_rate: 6.8493e-04
# Epoch 25/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1044 - mae: 0.1275
# Epoch 25: val_mae did not improve from 0.12332
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1044 - mae: 0.1275 - val_loss: 0.1033 - val_mae: 0.1241 - learning_rate: 6.7568e-04
# Epoch 26/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1036 - mae: 0.1273
# Epoch 26: val_mae improved from 0.12332 to 0.12271, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 169ms/step - loss: 0.1036 - mae: 0.1273 - val_loss: 0.1015 - val_mae: 0.1227 - learning_rate: 6.6667e-04
# Epoch 27/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1014 - mae: 0.1238
# Epoch 27: val_mae did not improve from 0.12271
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1014 - mae: 0.1239 - val_loss: 0.1004 - val_mae: 0.1233 - learning_rate: 6.5789e-04
# Epoch 28/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1014 - mae: 0.1270
# Epoch 28: val_mae did not improve from 0.12271
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1013 - mae: 0.1270 - val_loss: 0.0995 - val_mae: 0.1230 - learning_rate: 6.4935e-04
# Epoch 29/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1087 - mae: 0.1330
# Epoch 29: val_mae did not improve from 0.12271
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1086 - mae: 0.1330 - val_loss: 0.1001 - val_mae: 0.1250 - learning_rate: 6.4103e-04
# Epoch 30/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1004 - mae: 0.1289
# Epoch 30: val_mae improved from 0.12271 to 0.12222, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.1004 - mae: 0.1289 - val_loss: 0.0977 - val_mae: 0.1222 - learning_rate: 6.3291e-04
# Epoch 31/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0987 - mae: 0.1271
# Epoch 31: val_mae did not improve from 0.12222
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0987 - mae: 0.1271 - val_loss: 0.0994 - val_mae: 0.1269 - learning_rate: 6.2500e-04
# Epoch 32/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.1024 - mae: 0.1308
# Epoch 32: val_mae did not improve from 0.12222
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.1023 - mae: 0.1307 - val_loss: 0.0959 - val_mae: 0.1243 - learning_rate: 6.1728e-04
# Epoch 33/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0962 - mae: 0.1260
# Epoch 33: val_mae did not improve from 0.12222
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0962 - mae: 0.1260 - val_loss: 0.0947 - val_mae: 0.1230 - learning_rate: 6.0976e-04
# Epoch 34/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0947 - mae: 0.1248
# Epoch 34: val_mae improved from 0.12222 to 0.12159, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0947 - mae: 0.1248 - val_loss: 0.0934 - val_mae: 0.1216 - learning_rate: 6.0241e-04
# Epoch 35/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0984 - mae: 0.1341
# Epoch 35: val_mae did not improve from 0.12159
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0984 - mae: 0.1340 - val_loss: 0.0930 - val_mae: 0.1239 - learning_rate: 5.9524e-04
# Epoch 36/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0934 - mae: 0.1268
# Epoch 36: val_mae did not improve from 0.12159
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0934 - mae: 0.1268 - val_loss: 0.0921 - val_mae: 0.1228 - learning_rate: 5.8824e-04
# Epoch 37/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0921 - mae: 0.1250
# Epoch 37: val_mae improved from 0.12159 to 0.12056, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0921 - mae: 0.1250 - val_loss: 0.0896 - val_mae: 0.1206 - learning_rate: 5.8140e-04
# Epoch 38/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0908 - mae: 0.1251
# Epoch 38: val_mae did not improve from 0.12056
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0908 - mae: 0.1251 - val_loss: 0.0892 - val_mae: 0.1216 - learning_rate: 5.7471e-04
# Epoch 39/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0899 - mae: 0.1258
# Epoch 39: val_mae improved from 0.12056 to 0.12016, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0899 - mae: 0.1258 - val_loss: 0.0873 - val_mae: 0.1202 - learning_rate: 5.6818e-04
# Epoch 40/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0876 - mae: 0.1231
# Epoch 40: val_mae did not improve from 0.12016
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0877 - mae: 0.1231 - val_loss: 0.0868 - val_mae: 0.1225 - learning_rate: 5.6180e-04
# Epoch 41/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0871 - mae: 0.1231
# Epoch 41: val_mae did not improve from 0.12016
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0871 - mae: 0.1231 - val_loss: 0.0945 - val_mae: 0.1477 - learning_rate: 5.5556e-04
# Epoch 42/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0937 - mae: 0.1346
# Epoch 42: val_mae did not improve from 0.12016
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0937 - mae: 0.1345 - val_loss: 0.0872 - val_mae: 0.1239 - learning_rate: 5.4945e-04
# Epoch 43/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0876 - mae: 0.1277
# Epoch 43: val_mae improved from 0.12016 to 0.11499, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0876 - mae: 0.1277 - val_loss: 0.0832 - val_mae: 0.1150 - learning_rate: 5.4348e-04
# Epoch 44/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0855 - mae: 0.1263
# Epoch 44: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0855 - mae: 0.1263 - val_loss: 0.1724 - val_mae: 0.2910 - learning_rate: 5.3763e-04
# Epoch 45/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0824 - mae: 0.1206
# Epoch 45: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0824 - mae: 0.1206 - val_loss: 0.0949 - val_mae: 0.1454 - learning_rate: 5.3191e-04
# Epoch 46/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0793 - mae: 0.1140
# Epoch 46: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0793 - mae: 0.1140 - val_loss: 0.0984 - val_mae: 0.1566 - learning_rate: 5.2632e-04
# Epoch 47/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0777 - mae: 0.1144
# Epoch 47: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0777 - mae: 0.1144 - val_loss: 0.0862 - val_mae: 0.1432 - learning_rate: 5.2083e-04
# Epoch 48/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0786 - mae: 0.1173
# Epoch 48: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0787 - mae: 0.1173 - val_loss: 0.1184 - val_mae: 0.2094 - learning_rate: 5.1546e-04
# Epoch 49/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0783 - mae: 0.1174
# Epoch 49: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0783 - mae: 0.1174 - val_loss: 0.0816 - val_mae: 0.1241 - learning_rate: 5.1020e-04
# Epoch 50/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0760 - mae: 0.1136
# Epoch 50: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0760 - mae: 0.1136 - val_loss: 0.0778 - val_mae: 0.1254 - learning_rate: 5.0505e-04
# Epoch 51/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0738 - mae: 0.1116
# Epoch 51: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0738 - mae: 0.1116 - val_loss: 0.0819 - val_mae: 0.1292 - learning_rate: 5.0000e-04
# Epoch 52/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0744 - mae: 0.1163
# Epoch 52: val_mae did not improve from 0.11499
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0743 - mae: 0.1162 - val_loss: 0.0905 - val_mae: 0.1701 - learning_rate: 4.9505e-04
# Epoch 53/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0717 - mae: 0.1127
# Epoch 53: val_mae improved from 0.11499 to 0.10653, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0717 - mae: 0.1126 - val_loss: 0.0693 - val_mae: 0.1065 - learning_rate: 4.9020e-04
# Epoch 54/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0687 - mae: 0.1072
# Epoch 54: val_mae improved from 0.10653 to 0.10549, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0687 - mae: 0.1072 - val_loss: 0.0667 - val_mae: 0.1055 - learning_rate: 4.8544e-04
# Epoch 55/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0673 - mae: 0.1079
# Epoch 55: val_mae did not improve from 0.10549
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0673 - mae: 0.1079 - val_loss: 0.1290 - val_mae: 0.2448 - learning_rate: 4.8077e-04
# Epoch 56/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0650 - mae: 0.1041
# Epoch 56: val_mae did not improve from 0.10549
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0650 - mae: 0.1041 - val_loss: 0.1048 - val_mae: 0.1964 - learning_rate: 4.7619e-04
# Epoch 57/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0650 - mae: 0.1071
# Epoch 57: val_mae did not improve from 0.10549
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0650 - mae: 0.1070 - val_loss: 0.0794 - val_mae: 0.1555 - learning_rate: 4.7170e-04
# Epoch 58/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0633 - mae: 0.1050
# Epoch 58: val_mae did not improve from 0.10549
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0633 - mae: 0.1050 - val_loss: 0.0942 - val_mae: 0.1789 - learning_rate: 4.6729e-04
# Epoch 59/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0617 - mae: 0.1042
# Epoch 59: val_mae did not improve from 0.10549
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0617 - mae: 0.1042 - val_loss: 0.0813 - val_mae: 0.1631 - learning_rate: 4.6296e-04
# Epoch 60/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0616 - mae: 0.1065
# Epoch 60: val_mae did not improve from 0.10549
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0616 - mae: 0.1065 - val_loss: 0.1483 - val_mae: 0.2824 - learning_rate: 4.5872e-04
# Epoch 61/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0605 - mae: 0.1062
# Epoch 61: val_mae did not improve from 0.10549
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0605 - mae: 0.1062 - val_loss: 0.0932 - val_mae: 0.1845 - learning_rate: 4.5455e-04
# Epoch 62/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0588 - mae: 0.1044
# Epoch 62: val_mae did not improve from 0.10549
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0588 - mae: 0.1044 - val_loss: 0.0647 - val_mae: 0.1276 - learning_rate: 4.5045e-04
# Epoch 63/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0601 - mae: 0.1109
# Epoch 63: val_mae improved from 0.10549 to 0.10212, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0600 - mae: 0.1109 - val_loss: 0.0562 - val_mae: 0.1021 - learning_rate: 4.4643e-04
# Epoch 64/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0561 - mae: 0.1040
# Epoch 64: val_mae did not improve from 0.10212
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0561 - mae: 0.1040 - val_loss: 0.0732 - val_mae: 0.1463 - learning_rate: 4.4248e-04
# Epoch 65/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0558 - mae: 0.1042
# Epoch 65: val_mae did not improve from 0.10212
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0558 - mae: 0.1042 - val_loss: 0.0622 - val_mae: 0.1212 - learning_rate: 4.3860e-04
# Epoch 66/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0566 - mae: 0.1087
# Epoch 66: val_mae did not improve from 0.10212
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0566 - mae: 0.1086 - val_loss: 0.0885 - val_mae: 0.1950 - learning_rate: 4.3478e-04
# Epoch 67/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0553 - mae: 0.1104
# Epoch 67: val_mae did not improve from 0.10212
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0553 - mae: 0.1104 - val_loss: 0.1032 - val_mae: 0.2227 - learning_rate: 4.3103e-04
# Epoch 68/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0545 - mae: 0.1098
# Epoch 68: val_mae did not improve from 0.10212
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0545 - mae: 0.1097 - val_loss: 0.0583 - val_mae: 0.1178 - learning_rate: 4.2735e-04
# Epoch 69/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0536 - mae: 0.1104
# Epoch 69: val_mae did not improve from 0.10212
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0536 - mae: 0.1104 - val_loss: 0.0853 - val_mae: 0.1945 - learning_rate: 4.2373e-04
# Epoch 70/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0520 - mae: 0.1079
# Epoch 70: val_mae did not improve from 0.10212
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0520 - mae: 0.1079 - val_loss: 0.0815 - val_mae: 0.1900 - learning_rate: 4.2017e-04
# Epoch 71/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0521 - mae: 0.1114
# Epoch 71: val_mae improved from 0.10212 to 0.09729, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0520 - mae: 0.1114 - val_loss: 0.0457 - val_mae: 0.0973 - learning_rate: 4.1667e-04
# Epoch 72/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0500 - mae: 0.1071
# Epoch 72: val_mae did not improve from 0.09729
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0500 - mae: 0.1071 - val_loss: 0.0476 - val_mae: 0.1115 - learning_rate: 4.1322e-04
# Epoch 73/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0493 - mae: 0.1080
# Epoch 73: val_mae did not improve from 0.09729
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0493 - mae: 0.1080 - val_loss: 0.0988 - val_mae: 0.2171 - learning_rate: 4.0984e-04
# Epoch 74/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0483 - mae: 0.1081
# Epoch 74: val_mae improved from 0.09729 to 0.09621, saving model to /kaggle/working/agetask6.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 170ms/step - loss: 0.0483 - mae: 0.1081 - val_loss: 0.0427 - val_mae: 0.0962 - learning_rate: 4.0650e-04
# Epoch 75/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0469 - mae: 0.1070
# Epoch 75: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0469 - mae: 0.1070 - val_loss: 0.0511 - val_mae: 0.1310 - learning_rate: 4.0323e-04
# Epoch 76/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0467 - mae: 0.1089
# Epoch 76: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0467 - mae: 0.1089 - val_loss: 0.0504 - val_mae: 0.1277 - learning_rate: 4.0000e-04
# Epoch 77/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0451 - mae: 0.1058
# Epoch 77: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0451 - mae: 0.1058 - val_loss: 0.0863 - val_mae: 0.2099 - learning_rate: 3.9683e-04
# Epoch 78/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0460 - mae: 0.1105
# Epoch 78: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0460 - mae: 0.1105 - val_loss: 0.0529 - val_mae: 0.1263 - learning_rate: 3.9370e-04
# Epoch 79/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0682 - mae: 0.1494
# Epoch 79: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0681 - mae: 0.1492 - val_loss: 0.0564 - val_mae: 0.1315 - learning_rate: 3.9063e-04
# Epoch 80/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0559 - mae: 0.1302
# Epoch 80: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0559 - mae: 0.1302 - val_loss: 0.0551 - val_mae: 0.1303 - learning_rate: 3.8760e-04
# Epoch 81/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0547 - mae: 0.1318
# Epoch 81: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0547 - mae: 0.1318 - val_loss: 0.0528 - val_mae: 0.1302 - learning_rate: 3.8462e-04
# Epoch 82/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0533 - mae: 0.1308
# Epoch 82: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0532 - mae: 0.1307 - val_loss: 0.0511 - val_mae: 0.1248 - learning_rate: 3.8168e-04
# Epoch 83/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0505 - mae: 0.1247
# Epoch 83: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0505 - mae: 0.1247 - val_loss: 0.0521 - val_mae: 0.1293 - learning_rate: 3.7879e-04
# Epoch 84/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.0496 - mae: 0.1246
# Epoch 84: val_mae did not improve from 0.09621
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 168ms/step - loss: 0.0496 - mae: 0.1246 - val_loss: 0.0479 - val_mae: 0.1217 - learning_rate: 3.7594e-04
# Test results: {'loss': 0.04308517277240753, 'mae': 0.09657198935747147}
# Test Age MAE: 11.2024 years
# Test Total Loss: 0.0431
