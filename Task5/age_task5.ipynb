# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')


BASE_DIR = '/kaggle/input/utkface-new/UTKFace'
IMG_SIZE = (128, 128)
BATCH_SIZE = 128
EPOCHS = 100
MAX_AGE = 116.0
# Out:
# 2025-08-01 04:43:46.944941: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754023427.309354      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754023427.412904      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_data():
    images, ages = [], []
    for file in tqdm(os.listdir(BASE_DIR)):
        temp = file.split('_')
        if len(temp) >= 1 and temp[0].isdigit():
            ages.append(int(temp[0]) / MAX_AGE)  
            img_path = os.path.join(BASE_DIR, file)
            img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE, color_mode='grayscale')
            img = tf.keras.preprocessing.image.img_to_array(img) / 255.0
            images.append(img)
    
    images = np.array(images)
    ages = np.array(ages)
    return images, ages

# %%
def get_data_augmentation():
    return tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.2),
        tf.keras.layers.RandomContrast(0.1),
    ])

# %%
#Gradual decay of learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.001
    return initial_lr * (1.0 / (1.0 + 0.02 * epoch))

# %%
def build_model():
    inputs = Input(shape=(128, 128, 1))
    x = get_data_augmentation()(inputs)
    
    x = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = Dropout(0.6)(x)
    x = Dense(128, activation='relu')(x) 
    
    age_output = Dense(1, name='age')(x)  
    
    model = Model(inputs=inputs, outputs=age_output)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='mean_squared_error', 
        metrics=['mae']
    )
    model.summary()
    return model

# %%
def check_data_distribution(X_train, y_train_age, X_val, y_val_age, X_test, y_test_age):
    print(f"Training set: {len(X_train)} samples, Age mean: {np.mean(y_train_age) * MAX_AGE:.2f}")
    print(f"Validation set: {len(X_val)} samples, Age mean: {np.mean(y_val_age) * MAX_AGE:.2f}")
    print(f"Test set: {len(X_test)} samples, Age mean: {np.mean(y_test_age) * MAX_AGE:.2f}")

# %%
images, ages = load_data()
X_temp, X_test, y_temp_age, y_test_age = train_test_split(
    images, ages, test_size=0.1, random_state=42, shuffle=True
)
X_train, X_val, y_train_age, y_val_age = train_test_split(
    X_temp, y_temp_age,random_state=42, shuffle=True
)

check_data_distribution(X_train, y_train_age, X_val, y_val_age, X_test, y_test_age)
model = build_model()
checkpoint = ModelCheckpoint(
    '/kaggle/working/agetask5.weights.h5',
    monitor='val_mae',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose = 1
)
early_stopping = EarlyStopping(
    monitor='val_mae',
    patience=10,
    restore_best_weights=True,
    mode='min'
)
lr_scheduler = LearningRateScheduler(lr_schedule)

history = model.fit(
    X_train,
    y_train_age,
    validation_data=(X_val, y_val_age),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[checkpoint, early_stopping, lr_scheduler],
    verbose=1
)

model.load_weights('/kaggle/working/agetask5.weights.h5')
test_results = model.evaluate(
    X_test, y_test_age,
    verbose=0,
    return_dict=True
)
print("Test results:", test_results)
test_total_loss = test_results['loss']
test_age_mae = test_results['mae'] * MAX_AGE
print(f"Test Age MAE: {test_age_mae:.4f} years")
print(f"Test Total Loss: {test_total_loss:.4f}")
model.save('/kaggle/working/agetask5.h5')

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training Age MAE')
plt.plot(history.history['val_mae'], label='Validation Age MAE')
plt.title('Training vs Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.ylim(0, 0.2)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 23708/23708 [00:27<00:00, 855.96it/s]
# Training set: 16002 samples, Age mean: 33.43
# Validation set: 5335 samples, Age mean: 32.99
# Test set: 2371 samples, Age mean: 33.18
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │     4,194,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ age (Dense)                     │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,617,345 (17.61 MB)
#  Trainable params: 4,616,385 (17.61 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 59.8329 - mae: 3.0337
# Epoch 1: val_mae improved from inf to 0.28764, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 32s 201ms/step - loss: 59.1267 - mae: 3.0064 - val_loss: 0.2158 - val_mae: 0.2876 - learning_rate: 0.0010
# Epoch 2/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.2245 - mae: 0.2691
# Epoch 2: val_mae improved from 0.28764 to 0.18764, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 24s 189ms/step - loss: 0.2241 - mae: 0.2687 - val_loss: 0.1493 - val_mae: 0.1876 - learning_rate: 9.8039e-04
# Epoch 3/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 0.1548 - mae: 0.1886
# Epoch 3: val_mae improved from 0.18764 to 0.16765, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 181ms/step - loss: 0.1547 - mae: 0.1885 - val_loss: 0.1437 - val_mae: 0.1677 - learning_rate: 9.6154e-04
# Epoch 4/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 0.1418 - mae: 0.1676
# Epoch 4: val_mae improved from 0.16765 to 0.15464, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 182ms/step - loss: 0.1418 - mae: 0.1676 - val_loss: 0.1358 - val_mae: 0.1546 - learning_rate: 9.4340e-04
# Epoch 5/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1347 - mae: 0.1542
# Epoch 5: val_mae improved from 0.15464 to 0.14197, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 185ms/step - loss: 0.1347 - mae: 0.1541 - val_loss: 0.1299 - val_mae: 0.1420 - learning_rate: 9.2593e-04
# Epoch 6/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1288 - mae: 0.1438
# Epoch 6: val_mae improved from 0.14197 to 0.13336, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 185ms/step - loss: 0.1288 - mae: 0.1437 - val_loss: 0.1250 - val_mae: 0.1334 - learning_rate: 9.0909e-04
# Epoch 7/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1233 - mae: 0.1331
# Epoch 7: val_mae improved from 0.13336 to 0.12803, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 184ms/step - loss: 0.1233 - mae: 0.1331 - val_loss: 0.1213 - val_mae: 0.1280 - learning_rate: 8.9286e-04
# Epoch 8/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1225 - mae: 0.1328
# Epoch 8: val_mae did not improve from 0.12803
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 182ms/step - loss: 0.1225 - mae: 0.1328 - val_loss: 0.1213 - val_mae: 0.1302 - learning_rate: 8.7719e-04
# Epoch 9/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1202 - mae: 0.1317
# Epoch 9: val_mae did not improve from 0.12803
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 182ms/step - loss: 0.1202 - mae: 0.1317 - val_loss: 0.1191 - val_mae: 0.1284 - learning_rate: 8.6207e-04
# Epoch 10/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1194 - mae: 0.1308
# Epoch 10: val_mae did not improve from 0.12803
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 182ms/step - loss: 0.1194 - mae: 0.1308 - val_loss: 0.1176 - val_mae: 0.1282 - learning_rate: 8.4746e-04
# Epoch 11/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1183 - mae: 0.1317
# Epoch 11: val_mae improved from 0.12803 to 0.12722, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 185ms/step - loss: 0.1183 - mae: 0.1317 - val_loss: 0.1166 - val_mae: 0.1272 - learning_rate: 8.3333e-04
# Epoch 12/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1163 - mae: 0.1300
# Epoch 12: val_mae did not improve from 0.12722
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 184ms/step - loss: 0.1163 - mae: 0.1300 - val_loss: 0.1159 - val_mae: 0.1296 - learning_rate: 8.1967e-04
# Epoch 13/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1142 - mae: 0.1268
# Epoch 13: val_mae did not improve from 0.12722
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 182ms/step - loss: 0.1142 - mae: 0.1268 - val_loss: 0.1152 - val_mae: 0.1301 - learning_rate: 8.0645e-04
# Epoch 14/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1151 - mae: 0.1297
# Epoch 14: val_mae did not improve from 0.12722
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 182ms/step - loss: 0.1151 - mae: 0.1297 - val_loss: 0.1129 - val_mae: 0.1276 - learning_rate: 7.9365e-04
# Epoch 15/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1122 - mae: 0.1272
# Epoch 15: val_mae improved from 0.12722 to 0.12672, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 184ms/step - loss: 0.1122 - mae: 0.1272 - val_loss: 0.1116 - val_mae: 0.1267 - learning_rate: 7.8125e-04
# Epoch 16/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1122 - mae: 0.1287
# Epoch 16: val_mae did not improve from 0.12672
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 182ms/step - loss: 0.1122 - mae: 0.1287 - val_loss: 0.1112 - val_mae: 0.1300 - learning_rate: 7.6923e-04
# Epoch 17/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - loss: 0.1106 - mae: 0.1276
# Epoch 17: val_mae did not improve from 0.12672
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.1106 - mae: 0.1276 - val_loss: 0.1107 - val_mae: 0.1314 - learning_rate: 7.5758e-04
# Epoch 18/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1096 - mae: 0.1286
# Epoch 18: val_mae did not improve from 0.12672
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 184ms/step - loss: 0.1096 - mae: 0.1286 - val_loss: 0.1090 - val_mae: 0.1279 - learning_rate: 7.4627e-04
# Epoch 19/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1087 - mae: 0.1283
# Epoch 19: val_mae improved from 0.12672 to 0.12671, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 185ms/step - loss: 0.1087 - mae: 0.1283 - val_loss: 0.1077 - val_mae: 0.1267 - learning_rate: 7.3529e-04
# Epoch 20/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1079 - mae: 0.1286
# Epoch 20: val_mae did not improve from 0.12671
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 184ms/step - loss: 0.1079 - mae: 0.1286 - val_loss: 0.1068 - val_mae: 0.1283 - learning_rate: 7.2464e-04
# Epoch 21/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1066 - mae: 0.1271
# Epoch 21: val_mae improved from 0.12671 to 0.12603, saving model to /kaggle/working/agetask5.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 185ms/step - loss: 0.1066 - mae: 0.1271 - val_loss: 0.1053 - val_mae: 0.1260 - learning_rate: 7.1429e-04
# Epoch 22/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1067 - mae: 0.1301
# Epoch 22: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.1067 - mae: 0.1301 - val_loss: 0.1049 - val_mae: 0.1297 - learning_rate: 7.0423e-04
# Epoch 23/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1053 - mae: 0.1281
# Epoch 23: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.1053 - mae: 0.1281 - val_loss: 0.1037 - val_mae: 0.1286 - learning_rate: 6.9444e-04
# Epoch 24/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1038 - mae: 0.1272
# Epoch 24: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.1038 - mae: 0.1272 - val_loss: 0.1026 - val_mae: 0.1294 - learning_rate: 6.8493e-04
# Epoch 25/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1020 - mae: 0.1260
# Epoch 25: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.1020 - mae: 0.1260 - val_loss: 0.1013 - val_mae: 0.1274 - learning_rate: 6.7568e-04
# Epoch 26/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1025 - mae: 0.1296
# Epoch 26: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.1025 - mae: 0.1296 - val_loss: 0.1002 - val_mae: 0.1279 - learning_rate: 6.6667e-04
# Epoch 27/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.1001 - mae: 0.1262
# Epoch 27: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.1001 - mae: 0.1262 - val_loss: 0.0993 - val_mae: 0.1282 - learning_rate: 6.5789e-04
# Epoch 28/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0998 - mae: 0.1278
# Epoch 28: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.0998 - mae: 0.1278 - val_loss: 0.0991 - val_mae: 0.1316 - learning_rate: 6.4935e-04
# Epoch 29/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0989 - mae: 0.1288
# Epoch 29: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.0989 - mae: 0.1288 - val_loss: 0.0970 - val_mae: 0.1267 - learning_rate: 6.4103e-04
# Epoch 30/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0982 - mae: 0.1272
# Epoch 30: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.0982 - mae: 0.1272 - val_loss: 0.0966 - val_mae: 0.1294 - learning_rate: 6.3291e-04
# Epoch 31/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0965 - mae: 0.1272
# Epoch 31: val_mae did not improve from 0.12603
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 23s 183ms/step - loss: 0.0965 - mae: 0.1272 - val_loss: 0.0960 - val_mae: 0.1299 - learning_rate: 6.2500e-04
# Test results: {'loss': 0.10485576838254929, 'mae': 0.12472239136695862}
# Test Age MAE: 14.4678 years
# Test Total Loss: 0.1049
