# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, Input, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')


BASE_DIR = '/kaggle/input/utkface-new/UTKFace'
IMG_SIZE = (128, 128)
BATCH_SIZE = 128
EPOCHS = 100
MAX_AGE = 116.0
# Out:
# 2025-08-07 05:30:55.220340: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754544655.430719      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754544655.490943      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def load_data():
    images, ages = [], []
    for file in tqdm(os.listdir(BASE_DIR)):
        temp = file.split('_')
        if len(temp) >= 1 and temp[0].isdigit():
            ages.append(int(temp[0]) / MAX_AGE)  
            img_path = os.path.join(BASE_DIR, file)
            img = tf.keras.preprocessing.image.load_img(img_path, target_size=IMG_SIZE, color_mode='grayscale')
            img = tf.keras.preprocessing.image.img_to_array(img) / 255.0
            images.append(img)
    
    images = np.array(images)
    ages = np.array(ages)
    return images, ages

# %%
def get_data_augmentation():
    return tf.keras.Sequential([
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.2),
        tf.keras.layers.RandomZoom(0.2),
        tf.keras.layers.RandomContrast(0.1),
    ])

# %%
#Gradual decay of learning rate scheduler
def lr_schedule(epoch):
    initial_lr = 0.001
    return initial_lr * (1.0 / (1.0 + 0.02 * epoch))

# %%
def build_model():
    inputs = Input(shape=(128, 128, 1))
    x = get_data_augmentation()(inputs)
    
    x = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(x)
    x = Dropout(0.6)(x)
    x = Dense(128, activation='relu')(x) 
    
    age_output = Dense(1, name='age')(x)  
    
    model = Model(inputs=inputs, outputs=age_output)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss='mean_squared_error', 
        metrics=['mae']
    )
    model.summary()
    return model

# %%
def check_data_distribution(X_train, y_train_age, X_val, y_val_age, X_test, y_test_age):
    print(f"Training set: {len(X_train)} samples, Age mean: {np.mean(y_train_age) * MAX_AGE:.2f}")
    print(f"Validation set: {len(X_val)} samples, Age mean: {np.mean(y_val_age) * MAX_AGE:.2f}")
    print(f"Test set: {len(X_test)} samples, Age mean: {np.mean(y_test_age) * MAX_AGE:.2f}")

# %%
images, ages = load_data()
X_temp, X_test, y_temp_age, y_test_age = train_test_split(
    images, ages, test_size=0.1, random_state=42, shuffle=True
)
X_train, X_val, y_train_age, y_val_age = train_test_split(
    X_temp, y_temp_age,random_state=42, shuffle=True
)

check_data_distribution(X_train, y_train_age, X_val, y_val_age, X_test, y_test_age)
model = build_model()
checkpoint = ModelCheckpoint(
    '/kaggle/working/agetask2.weights.h5',
    monitor='val_mae',
    save_best_only=True,
    save_weights_only=True,
    mode='min',
    verbose=1
)
early_stopping = EarlyStopping(
    monitor='val_mae',
    patience=10,
    restore_best_weights=True,
    mode='min'
)
lr_scheduler = LearningRateScheduler(lr_schedule)
history = model.fit(
    X_train,
    y_train_age,
    validation_data=(X_val, y_val_age),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[checkpoint, early_stopping, lr_scheduler],
    verbose=1
)

model.load_weights('/kaggle/working/agetask2.weights.h5')
test_results = model.evaluate(
    X_test, y_test_age,
    verbose=0,
    return_dict=True
)
print("Test results:", test_results)
test_total_loss = test_results['loss']
test_age_mae = test_results['mae'] * MAX_AGE
print(f"Test Age MAE: {test_age_mae:.4f} years")
print(f"Test Total Loss: {test_total_loss:.4f}")

model.save('/kaggle/working/agetask2.h5')

plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['mae'], label='Training Age MAE')
plt.plot(history.history['val_mae'], label='Validation Age MAE')
plt.title('Training vs Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.ylim(0, 0.2)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 100%|██████████| 23708/23708 [02:33<00:00, 154.52it/s]
# Training set: 16002 samples, Age mean: 33.43
# Validation set: 5335 samples, Age mean: 32.99
# Test set: 2371 samples, Age mean: 33.18
# I0000 00:00:1754544893.491782      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1754544893.492396      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     4,194,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ age (Dense)                     │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,617,345 (17.61 MB)
#  Trainable params: 4,616,385 (17.61 MB)
#  Non-trainable params: 960 (3.75 KB)
# Epoch 1/100
# I0000 00:00:1754544905.527943      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 13.1917 - mae: 1.8871
# Epoch 1: val_mae improved from inf to 0.39868, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 33s 178ms/step - loss: 13.1200 - mae: 1.8792 - val_loss: 0.2944 - val_mae: 0.3987 - learning_rate: 0.0010
# Epoch 2/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.1633 - mae: 0.2021
# Epoch 2: val_mae improved from 0.39868 to 0.16344, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 166ms/step - loss: 0.1631 - mae: 0.2018 - val_loss: 0.1444 - val_mae: 0.1634 - learning_rate: 9.8039e-04
# Epoch 3/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - loss: 0.1357 - mae: 0.1543
# Epoch 3: val_mae improved from 0.16344 to 0.14166, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.1356 - mae: 0.1542 - val_loss: 0.1295 - val_mae: 0.1417 - learning_rate: 9.6154e-04
# Epoch 4/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.1241 - mae: 0.1318
# Epoch 4: val_mae improved from 0.14166 to 0.12776, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 174ms/step - loss: 0.1241 - mae: 0.1318 - val_loss: 0.1225 - val_mae: 0.1278 - learning_rate: 9.4340e-04
# Epoch 5/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - loss: 0.1220 - mae: 0.1314
# Epoch 5: val_mae improved from 0.12776 to 0.12612, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 175ms/step - loss: 0.1219 - mae: 0.1314 - val_loss: 0.1202 - val_mae: 0.1261 - learning_rate: 9.2593e-04
# Epoch 6/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1198 - mae: 0.1315
# Epoch 6: val_mae did not improve from 0.12612
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.1198 - mae: 0.1314 - val_loss: 0.1193 - val_mae: 0.1267 - learning_rate: 9.0909e-04
# Epoch 7/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1178 - mae: 0.1290
# Epoch 7: val_mae improved from 0.12612 to 0.12561, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: 0.1178 - mae: 0.1290 - val_loss: 0.1169 - val_mae: 0.1256 - learning_rate: 8.9286e-04
# Epoch 8/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1159 - mae: 0.1278
# Epoch 8: val_mae did not improve from 0.12561
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.1159 - mae: 0.1278 - val_loss: 0.1162 - val_mae: 0.1261 - learning_rate: 8.7719e-04
# Epoch 9/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.1150 - mae: 0.1276
# Epoch 9: val_mae improved from 0.12561 to 0.12500, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 174ms/step - loss: 0.1150 - mae: 0.1276 - val_loss: 0.1136 - val_mae: 0.1250 - learning_rate: 8.6207e-04
# Epoch 10/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1135 - mae: 0.1290
# Epoch 10: val_mae did not improve from 0.12500
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.1135 - mae: 0.1290 - val_loss: 0.1121 - val_mae: 0.1252 - learning_rate: 8.4746e-04
# Epoch 11/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1126 - mae: 0.1297
# Epoch 11: val_mae did not improve from 0.12500
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.1126 - mae: 0.1296 - val_loss: 0.1109 - val_mae: 0.1257 - learning_rate: 8.3333e-04
# Epoch 12/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1107 - mae: 0.1281
# Epoch 12: val_mae did not improve from 0.12500
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.1107 - mae: 0.1280 - val_loss: 0.1094 - val_mae: 0.1260 - learning_rate: 8.1967e-04
# Epoch 13/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1091 - mae: 0.1268
# Epoch 13: val_mae improved from 0.12500 to 0.12457, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: 0.1091 - mae: 0.1268 - val_loss: 0.1073 - val_mae: 0.1246 - learning_rate: 8.0645e-04
# Epoch 14/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1068 - mae: 0.1253
# Epoch 14: val_mae did not improve from 0.12457
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.1068 - mae: 0.1254 - val_loss: 0.1058 - val_mae: 0.1247 - learning_rate: 7.9365e-04
# Epoch 15/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1064 - mae: 0.1273
# Epoch 15: val_mae improved from 0.12457 to 0.12302, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: 0.1064 - mae: 0.1273 - val_loss: 0.1042 - val_mae: 0.1230 - learning_rate: 7.8125e-04
# Epoch 16/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1050 - mae: 0.1263
# Epoch 16: val_mae improved from 0.12302 to 0.12213, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: 0.1050 - mae: 0.1263 - val_loss: 0.1023 - val_mae: 0.1221 - learning_rate: 7.6923e-04
# Epoch 17/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.1033 - mae: 0.1258
# Epoch 17: val_mae improved from 0.12213 to 0.12037, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: 0.1033 - mae: 0.1258 - val_loss: 0.1007 - val_mae: 0.1204 - learning_rate: 7.5758e-04
# Epoch 18/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0998 - mae: 0.1202
# Epoch 18: val_mae did not improve from 0.12037
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0998 - mae: 0.1203 - val_loss: 0.0987 - val_mae: 0.1229 - learning_rate: 7.4627e-04
# Epoch 19/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0986 - mae: 0.1209
# Epoch 19: val_mae improved from 0.12037 to 0.11997, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: 0.0986 - mae: 0.1209 - val_loss: 0.0972 - val_mae: 0.1200 - learning_rate: 7.3529e-04
# Epoch 20/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0965 - mae: 0.1188
# Epoch 20: val_mae did not improve from 0.11997
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.0965 - mae: 0.1188 - val_loss: 0.0994 - val_mae: 0.1246 - learning_rate: 7.2464e-04
# Epoch 21/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0968 - mae: 0.1219
# Epoch 21: val_mae improved from 0.11997 to 0.11761, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: 0.0968 - mae: 0.1219 - val_loss: 0.0946 - val_mae: 0.1176 - learning_rate: 7.1429e-04
# Epoch 22/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0938 - mae: 0.1169
# Epoch 22: val_mae did not improve from 0.11761
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.0938 - mae: 0.1169 - val_loss: 0.0940 - val_mae: 0.1178 - learning_rate: 7.0423e-04
# Epoch 23/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0918 - mae: 0.1155
# Epoch 23: val_mae did not improve from 0.11761
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.0918 - mae: 0.1155 - val_loss: 0.0925 - val_mae: 0.1193 - learning_rate: 6.9444e-04
# Epoch 24/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0914 - mae: 0.1174
# Epoch 24: val_mae did not improve from 0.11761
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0914 - mae: 0.1174 - val_loss: 0.0942 - val_mae: 0.1223 - learning_rate: 6.8493e-04
# Epoch 25/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0896 - mae: 0.1156
# Epoch 25: val_mae did not improve from 0.11761
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.0896 - mae: 0.1156 - val_loss: 0.0957 - val_mae: 0.1389 - learning_rate: 6.7568e-04
# Epoch 26/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0875 - mae: 0.1132
# Epoch 26: val_mae did not improve from 0.11761
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.0875 - mae: 0.1132 - val_loss: 0.0909 - val_mae: 0.1283 - learning_rate: 6.6667e-04
# Epoch 27/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0871 - mae: 0.1144
# Epoch 27: val_mae did not improve from 0.11761
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0871 - mae: 0.1143 - val_loss: 0.0901 - val_mae: 0.1324 - learning_rate: 6.5789e-04
# Epoch 28/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0896 - mae: 0.1185
# Epoch 28: val_mae did not improve from 0.11761
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0896 - mae: 0.1184 - val_loss: 0.1113 - val_mae: 0.1831 - learning_rate: 6.4935e-04
# Epoch 29/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0840 - mae: 0.1127
# Epoch 29: val_mae did not improve from 0.11761
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.0840 - mae: 0.1127 - val_loss: 0.0852 - val_mae: 0.1250 - learning_rate: 6.4103e-04
# Epoch 30/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0813 - mae: 0.1089
# Epoch 30: val_mae improved from 0.11761 to 0.11450, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 173ms/step - loss: 0.0813 - mae: 0.1089 - val_loss: 0.0836 - val_mae: 0.1145 - learning_rate: 6.3291e-04
# Epoch 31/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0812 - mae: 0.1101
# Epoch 31: val_mae improved from 0.11450 to 0.11010, saving model to /kaggle/working/agetask2.weights.h5
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 174ms/step - loss: 0.0812 - mae: 0.1101 - val_loss: 0.0792 - val_mae: 0.1101 - learning_rate: 6.2500e-04
# Epoch 32/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0783 - mae: 0.1062
# Epoch 32: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0783 - mae: 0.1062 - val_loss: 0.1086 - val_mae: 0.1858 - learning_rate: 6.1728e-04
# Epoch 33/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0773 - mae: 0.1072
# Epoch 33: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0772 - mae: 0.1072 - val_loss: 0.0758 - val_mae: 0.1123 - learning_rate: 6.0976e-04
# Epoch 34/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0753 - mae: 0.1058
# Epoch 34: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0753 - mae: 0.1058 - val_loss: 0.0853 - val_mae: 0.1440 - learning_rate: 6.0241e-04
# Epoch 35/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0732 - mae: 0.1031
# Epoch 35: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0732 - mae: 0.1031 - val_loss: 0.0920 - val_mae: 0.1611 - learning_rate: 5.9524e-04
# Epoch 36/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0740 - mae: 0.1089
# Epoch 36: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0739 - mae: 0.1089 - val_loss: 0.0821 - val_mae: 0.1413 - learning_rate: 5.8824e-04
# Epoch 37/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0726 - mae: 0.1088
# Epoch 37: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0726 - mae: 0.1088 - val_loss: 0.0732 - val_mae: 0.1111 - learning_rate: 5.8140e-04
# Epoch 38/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0694 - mae: 0.1026
# Epoch 38: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - loss: 0.0693 - mae: 0.1026 - val_loss: 0.0712 - val_mae: 0.1111 - learning_rate: 5.7471e-04
# Epoch 39/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0685 - mae: 0.1042
# Epoch 39: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0685 - mae: 0.1042 - val_loss: 0.1247 - val_mae: 0.2255 - learning_rate: 5.6818e-04
# Epoch 40/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0671 - mae: 0.1031
# Epoch 40: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0671 - mae: 0.1031 - val_loss: 0.1010 - val_mae: 0.1885 - learning_rate: 5.6180e-04
# Epoch 41/100
# 125/126 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0685 - mae: 0.1108
# Epoch 41: val_mae did not improve from 0.11010
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 22s 172ms/step - loss: 0.0685 - mae: 0.1108 - val_loss: 0.0676 - val_mae: 0.1102 - learning_rate: 5.5556e-04
# Test results: {'loss': 0.07917086780071259, 'mae': 0.10927532613277435}
# Test Age MAE: 12.6759 years
# Test Total Loss: 0.0792
